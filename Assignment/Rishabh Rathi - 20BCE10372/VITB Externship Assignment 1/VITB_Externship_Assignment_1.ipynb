# %% [markdown]
# Name: Rishabh Rathi
#
# Registration Number : 20BCE10372

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Task 1 - Create a pandas dataframe (DataFrame name as 'df') with numpy random values. (4 features and 4 observation)

# %%
import pandas as pd
import numpy as np

# %%
s1 = pd.Series(np.random.rand(4))
s2 = pd.Series(np.random.rand(4))
s3 = pd.Series(np.random.rand(4))
s4 = pd.Series(np.random.rand(4))
df = pd.DataFrame([s1,s2,s3,s4])
df
# Out:
#           0         1         2         3
# 0  0.517081  0.630070  0.752322  0.922056
# 1  0.681453  0.691601  0.432659  0.446896
# 2  0.801235  0.145566  0.384421  0.888702
# 3  0.228632  0.128169  0.309469  0.225075

# %%
#Task 2 - Rename the task - 1 'df' dataframe column names to 'Random value 1', 'Random value 2', 'Random value 3' & 'Random value 4

# %%
df.columns = ['Random Value 1','Random Value 2','Random Value 3','Random Value 4']
df
# Out:
#    Random Value 1  Random Value 2  Random Value 3  Random Value 4
# 0        0.517081        0.630070        0.752322        0.922056
# 1        0.681453        0.691601        0.432659        0.446896
# 2        0.801235        0.145566        0.384421        0.888702
# 3        0.228632        0.128169        0.309469        0.225075

# %%
#Task 3 - Find the descriptive statistics of the 'df' dataframe.

# %%
df.describe(include='all')
# Out:
#        Random Value 1  Random Value 2  Random Value 3  Random Value 4
# count        4.000000        4.000000        4.000000        4.000000
# mean         0.557100        0.398851        0.469718        0.620682
# std          0.248031        0.303637        0.195102        0.341256
# min          0.228632        0.128169        0.309469        0.225075
# 25%          0.444969        0.141216        0.365683        0.391441
# 50%          0.599267        0.387818        0.408540        0.667799
# 75%          0.711399        0.645453        0.512575        0.897040
# max          0.801235        0.691601        0.752322        0.922056

# %%
#Task 4 - Check for the null values in 'df' and find the data type of the columns.

# %%
df.isnull()
# Out:
#    Random Value 1  Random Value 2  Random Value 3  Random Value 4
# 0           False           False           False           False
# 1           False           False           False           False
# 2           False           False           False           False
# 3           False           False           False           False

# %%
df['Random Value 1'].dtype
# Out:
# dtype('float64')

# %%
df['Random Value 2'].dtype
# Out:
# dtype('float64')

# %%
df['Random Value 3'].dtype
# Out:
# dtype('float64')

# %%
df['Random Value 4'].dtype
# Out:
# dtype('float64')

# %%
#Task 5 - Display the 'Random value 2' & 'Random value 3' columns with location method and index location method.

# %%
df.loc[0:4,'Random Value 2':'Random Value 3']
# Out:
#    Random Value 2  Random Value 3
# 0        0.630070        0.752322
# 1        0.691601        0.432659
# 2        0.145566        0.384421
# 3        0.128169        0.309469

# %%
df.iloc[0:,1:3]
# Out:
#    Random Value 2  Random Value 3
# 0        0.630070        0.752322
# 1        0.691601        0.432659
# 2        0.145566        0.384421
# 3        0.128169        0.309469
